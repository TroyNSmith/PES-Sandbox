# %%
import automol

smi = "FC=CF"

graph = automol.smiles.graph(smi)
graph
# Out:
# ({0: ('F', 0, None),
#   1: ('C', 0, None),
#   2: ('C', 0, None),
#   3: ('F', 0, None),
#   4: ('H', 0, None),
#   5: ('H', 0, None)},
#  {frozenset({0, 1}): (1, None),
#   frozenset({1, 2}): (1, None),
#   frozenset({2, 3}): (1, None),
#   frozenset({1, 4}): (1, None),
#   frozenset({2, 5}): (1, None)})

# %%
automol.graph.display(graph)

# %%
for g in automol.graph.expand_stereo(graph):
    automol.graph.display(g)
