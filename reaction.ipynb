# %%
import automol

re_smi = ("CC(O[O])CC",)
pr_smi = ("CC=CC", "O[O]")

rxns = automol.reac.from_smiles(re_smi, pr_smi)

# %%
dct = {}

for i, rxn in enumerate(rxns):
    automol.reac.display(rxn)
    dct[i] = automol.reac.ts_amchi(rxn)

# %%
dct
# Out:
# {0: 'AMChI=1/C4H9O2/c1-3-4(2)7-5-6-3/h3-4H,1-2H3/t3-,4-/m0/s1/k6-3,7-4/f7-5/r0',
#  1: 'AMChI=1/C4H9O2/c1-3-4(2)7-5-6-3/h3-4H,1-2H3/t3-,4+/m0/s1/k6-3,7-4/f7-5/r0',
#  2: 'AMChI=1/C4H9O2/c1-3-4(2)7-5-6-3/h3-4H,1-2H3/t3-,4+/m1/s1/k6-3,7-4/f7-5/r0',
#  3: 'AMChI=1/C4H9O2/c1-3-4(2)7-5-6-3/h3-4H,1-2H3/t3-,4-/m1/s1/k6-3,7-4/f7-5/r0'}
